# %% [markdown]
# # Import Packages and Data

# %%
# Import Packages
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
opioid_file = "/content/drive/Shareddrives/Capstone Project: GHUCCTS/Life Stress DT Capstone Project/Code/Opioid_synthetic20240306.R1.csv"
opioid_df = pd.read_csv(opioid_file)

# %%
opioid_df.shape
# Out:
# (205401, 48)

# %%
opioid_df.head()
# Out:
#                             HASHED_PERSONID SEX2019 RACE2019 ETHNICITY2019  \
# 0  7cd98e6f5cccd5871ccdde188131ecdc8149e150    Male    White       Unknown
# 1  597a91c395043f9956b55e7a1412a30b36a32971  Female    Black  Non-Hispanic
# 2  e1d6881469c57394534a1c62feb2f22fc09c9fad  Female    Black  Non-Hispanic
# 3  37387de9034a1d8b9ff7ca7036e140dcef343d77    Male    Black  Non-Hispanic
# 4  f2a0d314d64cb3ff1094bd5c2fd08c1018464921  Female    Black  Non-Hispanic
#
#   ZIPCODE2019 AGE_GROUP2019 HTN2017 DM2017 PTSD2017 ADDICTION2017 ALCOHOL2017  \
# 0        Z212            25     NaN    NaN      NaN           NaN         NaN
# 1        Z212            66     I10    NaN      NaN           NaN         NaN
# 2        Z206            76     NaN    NaN      NaN           NaN         NaN
# 3        Z212            70     I10  E13.9      NaN           NaN         NaN
# 4        Z210            42     I10    NaN   F43.12        F10.99      F10.21
#
# ...

# %% [markdown]
# # Filter Data
# ### Patients with No Opiod Abuse 2017 and yes Opiod Abuse 2018

# %%
opioid_df.shape
# Out:
# (205401, 48)

# %%
#opioid_use_df = opioid_df[
#    (opioid_df['OPIOIDABUSE2017'].isna()) &
#    (opioid_df['OPIOIDABUSE2018'].notna())
#]

opioid_use_df = opioid_df[
    (opioid_df['OPIOIDABUSE2017'].isna())
]

# %%
opioid_use_df.head()
# Out:
#                             HASHED_PERSONID SEX2019 RACE2019 ETHNICITY2019  \
# 0  7cd98e6f5cccd5871ccdde188131ecdc8149e150    Male    White       Unknown
# 1  597a91c395043f9956b55e7a1412a30b36a32971  Female    Black  Non-Hispanic
# 2  e1d6881469c57394534a1c62feb2f22fc09c9fad  Female    Black  Non-Hispanic
# 3  37387de9034a1d8b9ff7ca7036e140dcef343d77    Male    Black  Non-Hispanic
# 4  f2a0d314d64cb3ff1094bd5c2fd08c1018464921  Female    Black  Non-Hispanic
#
#   ZIPCODE2019 AGE_GROUP2019 HTN2017 DM2017 PTSD2017 ADDICTION2017 ALCOHOL2017  \
# 0        Z212            25     NaN    NaN      NaN           NaN         NaN
# 1        Z212            66     I10    NaN      NaN           NaN         NaN
# 2        Z206            76     NaN    NaN      NaN           NaN         NaN
# 3        Z212            70     I10  E13.9      NaN           NaN         NaN
# 4        Z210            42     I10    NaN   F43.12        F10.99      F10.21
#
# ...

# %%
opioid_use_df.shape
# Out:
# (199999, 48)

# %%
filtered_df = opioid_use_df[['OPIOIDABUSE2018']]
filtered_df.head()
# Out:
#   OPIOIDABUSE2018
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %% [markdown]
# # ICD Codes One Hot Encoded

# %%
opioid_use_df_copy = opioid_use_df.copy()

# %%
opioid_use_df_copy.head()
# Out:
#                             HASHED_PERSONID SEX2019 RACE2019 ETHNICITY2019  \
# 0  7cd98e6f5cccd5871ccdde188131ecdc8149e150    Male    White       Unknown
# 1  597a91c395043f9956b55e7a1412a30b36a32971  Female    Black  Non-Hispanic
# 2  e1d6881469c57394534a1c62feb2f22fc09c9fad  Female    Black  Non-Hispanic
# 3  37387de9034a1d8b9ff7ca7036e140dcef343d77    Male    Black  Non-Hispanic
# 4  f2a0d314d64cb3ff1094bd5c2fd08c1018464921  Female    Black  Non-Hispanic
#
#   ZIPCODE2019 AGE_GROUP2019 HTN2017 DM2017 PTSD2017 ADDICTION2017 ALCOHOL2017  \
# 0        Z212            25     NaN    NaN      NaN           NaN         NaN
# 1        Z212            66     I10    NaN      NaN           NaN         NaN
# 2        Z206            76     NaN    NaN      NaN           NaN         NaN
# 3        Z212            70     I10  E13.9      NaN           NaN         NaN
# 4        Z210            42     I10    NaN   F43.12        F10.99      F10.21
#
# ...

# %%
# remove the codes
columns_to_remove = [
    'HTN2018', 'DM2018', 'PTSD2018','ADDICTION2018', 'ALCOHOL2018', 'TOBACCO2018', 'OTHERDRUGS2018', 'ANXIETY2018', 'DEPRESSION2018', 'TBI2018',
    'BACKPAIN2018', 'NECKPAIN2018', 'CANCER2018', 'HTN2019', 'DM2019', 'PTSD2019','ADDICTION2019', 'ALCOHOL2019', 'TOBACCO2019', 'OTHERDRUGS2019', 'ANXIETY2019', 'DEPRESSION2019', 'TBI2019',
    'BACKPAIN2019', 'NECKPAIN2019', 'CANCER2019', 'OPIOIDABUSE2019','HASHED_PERSONID','ZIPCODE2019','OPIOIDABUSE2017'
]
#, 'HASHED_PERSONID'
opioid_use_df_copy = opioid_use_df_copy.drop(columns=columns_to_remove)

# %%
opioid_use_df_copy.columns
# Out:
# Index(['SEX2019', 'RACE2019', 'ETHNICITY2019', 'AGE_GROUP2019', 'HTN2017',
#        'DM2017', 'PTSD2017', 'ADDICTION2017', 'ALCOHOL2017', 'TOBACCO2017',
#        'OTHERDRUGS2017', 'ANXIETY2017', 'DEPRESSION2017', 'TBI2017',
#        'BACKPAIN2017', 'NECKPAIN2017', 'CANCER2017', 'OPIOIDABUSE2018'],
#       dtype='object')

# %%
df_encoded = pd.get_dummies(opioid_use_df_copy, columns=['HTN2017', 'DM2017', 'PTSD2017', 'ADDICTION2017', 'ALCOHOL2017', 'TOBACCO2017', 'OTHERDRUGS2017', 'ANXIETY2017', 'DEPRESSION2017', 'TBI2017', 'BACKPAIN2017', 'NECKPAIN2017', 'CANCER2017'], drop_first=True)

# %%
df_encoded.shape
# Out:
# (199999, 816)

# %%
df_encoded.to_csv('/content/drive/Shareddrives/Capstone Project: GHUCCTS/Life Stress DT Capstone Project/Code/opioid_training_data_ICD.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-150-a9a803dfcb10> in <cell line: 1>()
# ----> 1 df_encoded.to_csv('/content/drive/Shareddrives/Capstone Project: GHUCCTS/Life Stress DT Capstone Project/Code/opioid_training_data_ICD.csv', index=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3900         )
#    3901
# -> 3902         return DataFrameRenderer(formatter).to_csv(
#    3903             path_or_buf,
#    3904             lineterminator=lineterminator,
#
# ...

# %% [markdown]
# # Risk Score with Alcohol

# %%
# Import the alchohol file using the ID from its url
url = 'https://docs.google.com/spreadsheets/d/1nzsFgx9kHRYM9NBRWrIHtHvCr4_X7xCfI4hhUN_IezE/export?format=csv'
alcohol_df = pd.read_csv(url)

# %%
alcohol_df.head(5)
# Out:
#    ALCOHOL                                 Alcohol_Definition  \
# 0  F10.10                       Alcohol\tUse\tDisorder,\tMild
# 1      305  Nondependent use of drugs” or “Nondependent us...
# 2  F10.20                      Alcohol Use Disorder, Moderate
# 3  F10.21                        Alcohol Use Disorder, Severe
# 4  F10.99   Alcohol use, unspecified with unspecified alco...
#
#    Alcohol_Category  Alcohol_Chronic  Alcohol_Weights  AL      Alcohol_Labels  \
# 0                 1                0                1 NaN         Alcohol Use
# 1                 1                0                1 NaN       Alcohol Abuse
# 2                 1                1                3 NaN  Alcohol Dependence
# 3                 1                1                5 NaN                 NaN
# 4                 1                0                1 NaN                 NaN
#
#    Alcohol_Number
# 0             1.0
# 1             2.0
# 2             3.0
# 3             NaN
# 4             NaN

# %%
#alcohol_df['ALCOHOL'] = alcohol_df['ALCOHOL'].str.strip()

# %%
#alcohol_df = alcohol_df[['ALCOHOL','Alcohol_Weights']]

# %%
alcohol_df.head()
# Out:
#    ALCOHOL                                 Alcohol_Definition  \
# 0  F10.10                       Alcohol\tUse\tDisorder,\tMild
# 1      305  Nondependent use of drugs” or “Nondependent us...
# 2  F10.20                      Alcohol Use Disorder, Moderate
# 3  F10.21                        Alcohol Use Disorder, Severe
# 4  F10.99   Alcohol use, unspecified with unspecified alco...
#
#    Alcohol_Category  Alcohol_Chronic  Alcohol_Weights  AL      Alcohol_Labels  \
# 0                 1                0                1 NaN         Alcohol Use
# 1                 1                0                1 NaN       Alcohol Abuse
# 2                 1                1                3 NaN  Alcohol Dependence
# 3                 1                1                5 NaN                 NaN
# 4                 1                0                1 NaN                 NaN
#
#    Alcohol_Number
# 0             1.0
# 1             2.0
# 2             3.0
# 3             NaN
# 4             NaN

# %%
opioid_use_df_copy = opioid_use_df.copy()

# %%
opioid_use_df_copy.head()
# Out:
#                             HASHED_PERSONID SEX2019 RACE2019 ETHNICITY2019  \
# 0  7cd98e6f5cccd5871ccdde188131ecdc8149e150    Male    White       Unknown
# 1  597a91c395043f9956b55e7a1412a30b36a32971  Female    Black  Non-Hispanic
# 2  e1d6881469c57394534a1c62feb2f22fc09c9fad  Female    Black  Non-Hispanic
# 3  37387de9034a1d8b9ff7ca7036e140dcef343d77    Male    Black  Non-Hispanic
# 4  f2a0d314d64cb3ff1094bd5c2fd08c1018464921  Female    Black  Non-Hispanic
#
#   ZIPCODE2019 AGE_GROUP2019 HTN2017 DM2017 PTSD2017 ADDICTION2017  ...  \
# 0        Z212            25     NaN    NaN      NaN           NaN  ...
# 1        Z212            66     I10    NaN      NaN           NaN  ...
# 2        Z206            76     NaN    NaN      NaN           NaN  ...
# 3        Z212            70     I10  E13.9      NaN           NaN  ...
# 4        Z210            42     I10    NaN   F43.12        F10.99  ...
#
#   ALCOHOL2019 TOBACCO2019 OTHERDRUGS2019 ANXIETY2019 DEPRESSION2019 TBI2019  \
# ...

# %%
# remove uneeded columns
columns_to_remove = [
    'HTN2019', 'DM2019', 'PTSD2019', 'ADDICTION2019', 'ALCOHOL2019', 'TOBACCO2019', 'OTHERDRUGS2019', 'ANXIETY2019',
    'DEPRESSION2019', 'TBI2019', 'BACKPAIN2019', 'NECKPAIN2019', 'CANCER2019','OPIOIDABUSE2019','HTN2018', 'DM2018', 'PTSD2018', 'ADDICTION2018',
    'ALCOHOL2018', 'TOBACCO2018', 'OTHERDRUGS2018', 'ANXIETY2018', 'DEPRESSION2018', 'TBI2018', 'BACKPAIN2018',
    'NECKPAIN2018', 'CANCER2018','HASHED_PERSONID', 'ZIPCODE2019'
]
#, 'HASHED_PERSONID'
opioid_use_df_copy = opioid_use_df_copy.drop(columns=columns_to_remove)

# %%
opioid_use_df_copy = pd.merge(opioid_use_df_copy, alcohol_df, left_on='ALCOHOL2017', right_on='ALCOHOL', how='left')

# %%
opioid_use_df_copy.head(11)
# Out:
#    SEX2019               RACE2019 ETHNICITY2019 AGE_GROUP2019 HTN2017 DM2017  \
# 0     Male                  White       Unknown            25     NaN    NaN
# 1   Female                  Black  Non-Hispanic            66     I10    NaN
# 2   Female                  Black  Non-Hispanic            76     NaN    NaN
# 3     Male                  Black  Non-Hispanic            70     I10  E13.9
# 4   Female                  Black  Non-Hispanic            42     I10    NaN
# 5   Female                  Black  Non-Hispanic            53     I10    NaN
# 6   Female                  White  Non-Hispanic            77     I10    NaN
# 7     Male  Bi-Racial/Multiracial  Non-Hispanic            45     NaN    NaN
# 8     Male                  White  Non-Hispanic            35     I10  E11.9
# 9   Female                  White  Non-Hispanic            35   401.9    NaN
# 10    Male                  White  Non-Hispanic            80     I10    NaN
#
# ...

# %%
opioid_use_df_copy.rename(columns={'Alcohol_Weights': 'Alcohol Risk Score'}, inplace=True)

# %% [markdown]
# # Risk Score with Addiction

# %%
url_addiction = 'https://docs.google.com/spreadsheets/d/1lg-qVcpI5KKARyRvDNEnZ_WvNQe52imU6OesJYxwyAU/export?format=csv'
addiction_df = pd.read_csv(url_addiction)

# %%
addiction_df.tail()
# Out:
#    ADDICTION                            Addiction_Definition  \
# 15   F14.21                 Cocaine dependence, in remission
# 16  F17.211    Nicotine dependence, cigarettes, in remission
# 17  F17.201   Nicotine dependence, unspecified, in remission
# 18     305.2                     Nondependent cannabis abuse
# 19    305.22                        Cannabis abuse, episodic
#
#     Addiction_Category  Addiction_Chronic  Addiction_Weights  Unnamed: 5  \
# 15                   6                  0                  1         NaN
# 16                   1                  0                  1         NaN
# 17                   1                  0                  1         NaN
# 18                   4                  1                  3         NaN
# 19                   4                  1                  3         NaN
#
#    Addiction_Labels  Addiction_Number
# 15              NaN               NaN
# 16              NaN               NaN
# 17              NaN               NaN
# ...

# %%
addiction_df['ADDICTION'] = addiction_df['ADDICTION'].str.strip()

# %%
addiction_df = addiction_df[['ADDICTION','Addiction_Weights']]

# %%
addiction_df.head()
# Out:
#   ADDICTION  Addiction_Weights
# 0     305.1                  5
# 1   F17.210                  5
# 2   F19.929                  3
# 3   F17.200                  5
# 4    F19.90                  3

# %%
opioid_use_df_copy = pd.merge(opioid_use_df_copy, addiction_df, left_on='ADDICTION2017', right_on='ADDICTION', how='left')

# %%
opioid_use_df_copy.head()
# Out:
#   SEX2019 RACE2019 ETHNICITY2019 AGE_GROUP2019 HTN2017 DM2017 PTSD2017  \
# 0    Male    White       Unknown            25     NaN    NaN      NaN
# 1  Female    Black  Non-Hispanic            66     I10    NaN      NaN
# 2  Female    Black  Non-Hispanic            76     NaN    NaN      NaN
# 3    Male    Black  Non-Hispanic            70     I10  E13.9      NaN
# 4  Female    Black  Non-Hispanic            42     I10    NaN   F43.12
#
#   ADDICTION2017 ALCOHOL2017 TOBACCO2017  ... ALCOHOL Alcohol_Definition  \
# 0           NaN         NaN         NaN  ...     NaN                NaN
# 1           NaN         NaN         NaN  ...     NaN                NaN
# 2           NaN         NaN         NaN  ...     NaN                NaN
# 3           NaN         NaN         NaN  ...     NaN                NaN
# 4        F10.99      F10.21     F17.210  ...     NaN                NaN
#
#   Alcohol_Category Alcohol_Chronic Alcohol Risk Score  AL Alcohol_Labels  \
# ...

# %%
opioid_use_df_copy.rename(columns={'Addiction_Weights': 'Addiction Risk Score'}, inplace=True)

# %% [markdown]
# # Risk Score with Anxiety

# %%
url_anxiety = 'https://docs.google.com/spreadsheets/d/18DuJgCTOCEQ_26HdpE_HNOtQ3EWPR7htZvkJ4PNinWw/export?format=csv'
anxiety_df = pd.read_csv(url_anxiety)

# %%
anxiety_df.tail()
# Out:
#    ANXIETY                                 Anxiety_Definition  \
# 8   F41.0        Panic disorder (episodic paroxysmal anxiety)
# 9   309.28  Adjustment disorder with mixed anxiety and dep...
# 10  300.09                               Other anxiety states
# 11  309.24                   Adjustment disorder with anxiety
# 12  F41.3                       Other mixed anxiety disorders
#
#     Anxiety_Category  Anxiety_Chronic  Anxiety_Weights  AL Anxiety_Labels  \
# 8                  3                1                5 NaN            NaN
# 9                  5                0                1 NaN            NaN
# 10                 1                1                3 NaN            NaN
# 11                 4                0                1 NaN            NaN
# 12                 6                1                3 NaN            NaN
#
#     Anxiety_Number
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN

# %%
anxiety_df['ANXIETY'] = anxiety_df['ANXIETY'].str.strip()

# %%
anxiety_df = anxiety_df[['ANXIETY','Anxiety_Weights']]

# %%
anxiety_df.head()
# Out:
#   ANXIETY  Anxiety_Weights
# 0   F41.9                3
# 1     300                3
# 2   F41.8                3
# 3   F41.1                3
# 4  F43.23                1

# %%
opioid_use_df_copy = pd.merge(opioid_use_df_copy, anxiety_df, left_on='ANXIETY2017', right_on='ANXIETY', how='left')

# %%
opioid_use_df_copy.head()
# Out:
#   SEX2019 RACE2019 ETHNICITY2019 AGE_GROUP2019 HTN2017 DM2017 PTSD2017  \
# 0    Male    White       Unknown            25     NaN    NaN      NaN
# 1  Female    Black  Non-Hispanic            66     I10    NaN      NaN
# 2  Female    Black  Non-Hispanic            76     NaN    NaN      NaN
# 3    Male    Black  Non-Hispanic            70     I10  E13.9      NaN
# 4  Female    Black  Non-Hispanic            42     I10    NaN   F43.12
#
#   ADDICTION2017 ALCOHOL2017 TOBACCO2017  ... Alcohol_Category Alcohol_Chronic  \
# 0           NaN         NaN         NaN  ...              NaN             NaN
# 1           NaN         NaN         NaN  ...              NaN             NaN
# 2           NaN         NaN         NaN  ...              NaN             NaN
# 3           NaN         NaN         NaN  ...              NaN             NaN
# 4        F10.99      F10.21     F17.210  ...              NaN             NaN
#
#   Alcohol Risk Score  AL Alcohol_Labels Alcohol_Number ADDICTION  \
# ...

# %%
opioid_use_df_copy.rename(columns={'Anxiety_Weights': 'Anxiety Risk Score'}, inplace=True)

# %% [markdown]
# # Risk Score with Depression

# %%
url_depression = 'https://docs.google.com/spreadsheets/d/1_0KX2m3gge6hdSangDEBXrOk1KtgKGiOUQeMSZSpcsM/export?format=csv'
depression_df = pd.read_csv(url_depression)

# %%
depression_df.tail()
# Out:
#    DEPRESSION                              Depression_Definition  \
# 15     F32.1   Major depressive disorder, single episode, mod...
# 16     F32.0     Major depressive disorder, single episode, mild
# 17      296.6  Bipolar disorder, current episode mixed, unspe...
# 18      296.3  Major depressive disorder, recurrent, unspecified
# 19     F33.8                Other recurrent depressive disorders
#
#     Depression_Category  Depression_Chronic  Depression_Weights  Unnamed: 5  \
# 15                    1                   0                   1         NaN
# 16                    1                   0                   1         NaN
# 17                    4                   1                   3         NaN
# 18                    1                   1                   3         NaN
# 19                    1                   1                   3         NaN
#
#    Depression_Labels  Depression_Number
# 15               NaN                NaN
# ...

# %%
depression_df['DEPRESSION'] = depression_df['DEPRESSION'].str.strip()

# %%
depression_df = depression_df[['DEPRESSION','Depression_Weights']]

# %%
depression_df.head()
# Out:
#   DEPRESSION  Depression_Weights
# 0      F32.9                   1
# 1        311                   1
# 2      F34.1                   3
# 3      F33.1                   3
# 4        F39                   3

# %%
opioid_use_df_copy = pd.merge(opioid_use_df_copy, depression_df, left_on='DEPRESSION2017', right_on='DEPRESSION', how='left')

# %%
opioid_use_df_copy.head()
# Out:
#   SEX2019 RACE2019 ETHNICITY2019 AGE_GROUP2019 HTN2017 DM2017 PTSD2017  \
# 0    Male    White       Unknown            25     NaN    NaN      NaN
# 1  Female    Black  Non-Hispanic            66     I10    NaN      NaN
# 2  Female    Black  Non-Hispanic            76     NaN    NaN      NaN
# 3    Male    Black  Non-Hispanic            70     I10  E13.9      NaN
# 4  Female    Black  Non-Hispanic            42     I10    NaN   F43.12
#
#   ADDICTION2017 ALCOHOL2017 TOBACCO2017  ... Alcohol Risk Score  AL  \
# 0           NaN         NaN         NaN  ...                NaN NaN
# 1           NaN         NaN         NaN  ...                NaN NaN
# 2           NaN         NaN         NaN  ...                NaN NaN
# 3           NaN         NaN         NaN  ...                NaN NaN
# 4        F10.99      F10.21     F17.210  ...                NaN NaN
#
#   Alcohol_Labels Alcohol_Number ADDICTION Addiction Risk Score ANXIETY  \
# ...

# %%
opioid_use_df_copy.rename(columns={'Depression_Weights': 'Depression Risk Score'}, inplace=True)

# %% [markdown]
# # Risk Score for HTN

# %%
url_HTN = 'https://docs.google.com/spreadsheets/d/10mgmEj28F8XAlcqFf46Ogx5Yqy3MdddrMuBDCmEgOow/export?format=csv'
HTN_df = pd.read_csv(url_HTN)

# %%
HTN_df.tail()
# Out:
#      HTN                                HTN_Definition  HTN_Category  \
# 0   I10               essential (primary) hypertension             1
# 1  401.9            unspecified essential hypertension             1
# 2  401.1                 benign essential hypertension             2
# 3    401  Non-specific code 401 Essential hypertension             1
#
#    HTN_Chronic  HTN_Weights  Unnamed: 5                HTN_Labels  HTN_Number
# 0            1            3         NaN    essential hypertension         1.0
# 1            1            3         NaN  unessential hypertension         2.0
# 2            0            1         NaN                       NaN         NaN
# 3            1            3         NaN                       NaN         NaN

# %%
HTN_df['HTN'] = HTN_df['HTN'].str.strip()

# %%
HTN_df = HTN_df[['HTN','HTN_Weights']]

# %%
HTN_df.head()
# Out:
#      HTN  HTN_Weights
# 0    I10            3
# 1  401.9            3
# 2  401.1            1
# 3    401            3

# %%
opioid_use_df_copy = pd.merge(opioid_use_df_copy, HTN_df, left_on='HTN2017', right_on='HTN', how='left')

# %%
opioid_use_df_copy.head()
# Out:
#   SEX2019 RACE2019 ETHNICITY2019 AGE_GROUP2019 HTN2017 DM2017 PTSD2017  \
# 0    Male    White       Unknown            25     NaN    NaN      NaN
# 1  Female    Black  Non-Hispanic            66     I10    NaN      NaN
# 2  Female    Black  Non-Hispanic            76     NaN    NaN      NaN
# 3    Male    Black  Non-Hispanic            70     I10  E13.9      NaN
# 4  Female    Black  Non-Hispanic            42     I10    NaN   F43.12
#
#   ADDICTION2017 ALCOHOL2017 TOBACCO2017  ... Alcohol_Labels Alcohol_Number  \
# 0           NaN         NaN         NaN  ...            NaN            NaN
# 1           NaN         NaN         NaN  ...            NaN            NaN
# 2           NaN         NaN         NaN  ...            NaN            NaN
# 3           NaN         NaN         NaN  ...            NaN            NaN
# 4        F10.99      F10.21     F17.210  ...            NaN            NaN
#
#   ADDICTION Addiction Risk Score ANXIETY Anxiety Risk Score DEPRESSION  \
# ...

# %%
opioid_use_df_copy.rename(columns={'HTN_Weights': 'HTN Risk Score'}, inplace=True)

# %% [markdown]
# # Risk Score for OTHERDRUGS

# %%
url_OTHERDRUGS = 'https://docs.google.com/spreadsheets/d/1levO4uL3KgEgo-zj0W_0bAuiL9XBDtV58Z38nzA1nWU/export?format=csv'
OTHERDRUGS_df = pd.read_csv(url_OTHERDRUGS)

# %%
OTHERDRUGS_df.tail()
# Out:
#    OTHERDRUGS                              OTHERDRUGS_Definition  \
# 15      305.2                        Nondependent cannabis abuse
# 16      304.9                       Unspecified drug dependence.
# 17   F13.239   Sedative, hypnotic or anxiolytic dependence wi...
# 18     305.93  Other, mixed, or unspecified drug abuse, in re...
# 19      305.9  Nondependent other mixed or unspecified drug a...
#
#     OTHERDRUGS_Category  OTHERDRUGS_Chronic  OTHERDRUGS_Weights  Unnamed: 5  \
# 15                    1                   1                   3         NaN
# 16                   11                   1                   5         NaN
# 17                    6                   1                   5         NaN
# 18                   12                   0                   1         NaN
# 19                   12                   1                   3         NaN
#
#    OTHERDRUGS_Labels  OTHERDRUGS_Number
# 15               NaN                NaN
# ...

# %%
OTHERDRUGS_df['OTHERDRUGS'] = OTHERDRUGS_df['OTHERDRUGS'].str.strip()

# %%
OTHERDRUGS_df = OTHERDRUGS_df[['OTHERDRUGS','OTHERDRUGS_Weights']]

# %%
OTHERDRUGS_df.head()
# Out:
#   OTHERDRUGS  OTHERDRUGS_Weights
# 0     305.23                   1
# 1     F12.10                   1
# 2    F19.929                   1
# 3     F19.10                   1
# 4      305.6                   3

# %%
opioid_use_df_copy = pd.merge(opioid_use_df_copy, OTHERDRUGS_df, left_on='OTHERDRUGS2017', right_on='OTHERDRUGS', how='left')

# %%
opioid_use_df_copy.head()
# Out:
#   SEX2019 RACE2019 ETHNICITY2019 AGE_GROUP2019 HTN2017 DM2017 PTSD2017  \
# 0    Male    White       Unknown            25     NaN    NaN      NaN
# 1  Female    Black  Non-Hispanic            66     I10    NaN      NaN
# 2  Female    Black  Non-Hispanic            76     NaN    NaN      NaN
# 3    Male    Black  Non-Hispanic            70     I10  E13.9      NaN
# 4  Female    Black  Non-Hispanic            42     I10    NaN   F43.12
#
#   ADDICTION2017 ALCOHOL2017 TOBACCO2017  ... ADDICTION Addiction Risk Score  \
# 0           NaN         NaN         NaN  ...       NaN                  NaN
# 1           NaN         NaN         NaN  ...       NaN                  NaN
# 2           NaN         NaN         NaN  ...       NaN                  NaN
# 3           NaN         NaN         NaN  ...       NaN                  NaN
# 4        F10.99      F10.21     F17.210  ...       NaN                  NaN
#
#   ANXIETY Anxiety Risk Score DEPRESSION Depression Risk Score  HTN  \
# ...

# %%
opioid_use_df_copy.rename(columns={'OTHERDRUGS_Weights': 'OTHERDRUGS Risk Score'}, inplace=True)

# %% [markdown]
# # Risk Score for PTSD

# %%
url_PTSD= 'https://docs.google.com/spreadsheets/d/1H2Kg9PkEWqLbpESKv88ZrH5gwh3uMyOQQSgmkJmt5R4/export?format=csv'
PTSD_df = pd.read_csv(url_PTSD)

# %%
PTSD_df.tail()
# Out:
#       PTSD                          PTSD_Definition  PTSD_Category  \
# 0  F43.10      acute post-traumatic stress disorder              1
# 1   309.81            Posttraumatic stress disorder              2
# 2  F43.12   Post-traumatic stress disorder, chronic              2
# 3   F43.11    Post-traumatic stress disorder, acute              1
#
#    PTSD_Chronic  PTSD_Weights  Unnamed: 5  \
# 0             0             1         NaN
# 1             1             3         NaN
# 2             1             3         NaN
# 3             0             1         NaN
#
#                               PTSD_Labels  PTSD_Number
# 0    acute post-traumatic stress disorder          1.0
# 1  chronic post-traumatic stress disorder          2.0
# 2                                     NaN          NaN
# 3                                     NaN          NaN

# %%
PTSD_df['PTSD'] = PTSD_df['PTSD'].str.strip()

# %%
PTSD_df = PTSD_df[['PTSD','PTSD_Weights']]

# %%
PTSD_df.head()
# Out:
#      PTSD  PTSD_Weights
# 0  F43.10             1
# 1  309.81             3
# 2  F43.12             3
# 3  F43.11             1

# %%
opioid_use_df_copy = pd.merge(opioid_use_df_copy, PTSD_df, left_on='PTSD2017', right_on='PTSD', how='left')

# %%
opioid_use_df_copy.head()
# Out:
#   SEX2019 RACE2019 ETHNICITY2019 AGE_GROUP2019 HTN2017 DM2017 PTSD2017  \
# 0    Male    White       Unknown            25     NaN    NaN      NaN
# 1  Female    Black  Non-Hispanic            66     I10    NaN      NaN
# 2  Female    Black  Non-Hispanic            76     NaN    NaN      NaN
# 3    Male    Black  Non-Hispanic            70     I10  E13.9      NaN
# 4  Female    Black  Non-Hispanic            42     I10    NaN   F43.12
#
#   ADDICTION2017 ALCOHOL2017 TOBACCO2017  ... ANXIETY Anxiety Risk Score  \
# 0           NaN         NaN         NaN  ...     NaN                NaN
# 1           NaN         NaN         NaN  ...     NaN                NaN
# 2           NaN         NaN         NaN  ...     NaN                NaN
# 3           NaN         NaN         NaN  ...     NaN                NaN
# 4        F10.99      F10.21     F17.210  ...     NaN                NaN
#
#   DEPRESSION Depression Risk Score  HTN HTN Risk Score OTHERDRUGS  \
# ...

# %%
opioid_use_df_copy.rename(columns={'PTSD_Weights': 'PTSD Risk Score'}, inplace=True)

# %% [markdown]
# # Risk Score for Tobacco

# %%
url_Tobacco = 'https://docs.google.com/spreadsheets/d/17sdh4Js2dosjm_TNS5pyVkJy_L6q5lEGI_7us55PzXc/export?format=csv'
Tobacco_df = pd.read_csv(url_Tobacco)

# %%
Tobacco_df.tail()
# Out:
#      TOBACCO                                 Tobacco_Definition  \
# 14  F17.221   Nicotine dependence, chewing tobacco, in remis...
# 15  F17.228   Nicotine dependence, chewing tobacco, with oth...
# 16  F17.293   Nicotine dependence, other tobacco product, wi...
# 17  F17.298   Nicotine dependence, other tobacco product, wi...
# 18  F17.208   Nicotine dependence, unspecified, with other n...
#
#     Tobacco_Category  Tobacco_Chronic  Tobacco_Weights  Unnamed: 5  \
# 14                 4                0                1         NaN
# 15                 4                1                5         NaN
# 16                 3                1                3         NaN
# 17                 3                1                5         NaN
# 18                 2                1                3         NaN
#
#    Tobacco_Labels  Tobacco_Number
# 14            NaN             NaN
# 15            NaN             NaN
# 16            NaN             NaN
# 17            NaN             NaN
# ...

# %%
Tobacco_df['TOBACCO'] = Tobacco_df['TOBACCO'].str.strip()

# %%
Tobacco_df = Tobacco_df[['TOBACCO','Tobacco_Weights']]

# %%
Tobacco_df.head()
# Out:
#    TOBACCO  Tobacco_Weights
# 0  F17.210                3
# 1    305.1                3
# 2  F17.200                3
# 3  F17.290                3
# 4  F17.220                3

# %%
opioid_use_df_copy = pd.merge(opioid_use_df_copy, Tobacco_df, left_on='TOBACCO2017', right_on='TOBACCO', how='left')

# %%
opioid_use_df_copy.head()
# Out:
#   SEX2019 RACE2019 ETHNICITY2019 AGE_GROUP2019 HTN2017 DM2017 PTSD2017  \
# 0    Male    White       Unknown            25     NaN    NaN      NaN
# 1  Female    Black  Non-Hispanic            66     I10    NaN      NaN
# 2  Female    Black  Non-Hispanic            76     NaN    NaN      NaN
# 3    Male    Black  Non-Hispanic            70     I10  E13.9      NaN
# 4  Female    Black  Non-Hispanic            42     I10    NaN   F43.12
#
#   ADDICTION2017 ALCOHOL2017 TOBACCO2017  ... DEPRESSION Depression Risk Score  \
# 0           NaN         NaN         NaN  ...        NaN                   NaN
# 1           NaN         NaN         NaN  ...        NaN                   NaN
# 2           NaN         NaN         NaN  ...        NaN                   NaN
# 3           NaN         NaN         NaN  ...        NaN                   NaN
# 4        F10.99      F10.21     F17.210  ...     F43.21                   1.0
#
#    HTN HTN Risk Score OTHERDRUGS OTHERDRUGS Risk Score    PTSD  \
# ...

# %%
opioid_use_df_copy.rename(columns={'Tobacco_Weights': 'Tobacco Risk Score'}, inplace=True)

# %% [markdown]
# # Risk Score for DM

# %%
url_DM = 'https://docs.google.com/spreadsheets/d/1S_58YGSxJNuWSC2w063-pqcaO4emQGGo3cm0QieSWK8/export?format=csv'
DM_df = pd.read_csv(url_DM)

# %%
DM_df.tail()
# Out:
#            DM                                      DM_Definition  DM_Category  \
# 17  E13.3219   Other specified diabetes mellitus with mild no...            3
# 18   E11.339   Type 2 diabetes mellitus with unspecified diab...            2
# 19  E10.3299   Type 1 diabetes mellitus with unspecified diab...            1
# 20    E10.65         Type 1 diabetes mellitus with hyperglycemia            1
# 21     250.01  Diabetes mellitus without mention of complicat...            4
#
#     DM_Chronic  DM_Weights  Unnamed: 5 DM_Labels  DM_Number
# 17           1           5         NaN       NaN        NaN
# 18           1           5         NaN       NaN        NaN
# 19           1           1         NaN       NaN        NaN
# 20           1           1         NaN       NaN        NaN
# 21           1           1         NaN       NaN        NaN

# %%
DM_df['DM'] = DM_df['DM'].str.strip()

# %%
DM_df = DM_df[['DM','DM_Weights']]

# %%
DM_df.head()
# Out:
#        DM  DM_Weights
# 0   E11.9           1
# 1   E13.9           3
# 2     250           5
# 3  E11.65           5
# 4  E13.10           5

# %%
opioid_use_df_copy = pd.merge(opioid_use_df_copy, DM_df, left_on='DM2017', right_on='DM', how='left')

# %%
opioid_use_df_copy.head()
# Out:
#   SEX2019 RACE2019 ETHNICITY2019 AGE_GROUP2019 HTN2017 DM2017 PTSD2017  \
# 0    Male    White       Unknown            25     NaN    NaN      NaN
# 1  Female    Black  Non-Hispanic            66     I10    NaN      NaN
# 2  Female    Black  Non-Hispanic            76     NaN    NaN      NaN
# 3    Male    Black  Non-Hispanic            70     I10  E13.9      NaN
# 4  Female    Black  Non-Hispanic            42     I10    NaN   F43.12
#
#   ADDICTION2017 ALCOHOL2017 TOBACCO2017  ...  HTN HTN Risk Score OTHERDRUGS  \
# 0           NaN         NaN         NaN  ...  NaN            NaN        NaN
# 1           NaN         NaN         NaN  ...  I10            3.0        NaN
# 2           NaN         NaN         NaN  ...  NaN            NaN        NaN
# 3           NaN         NaN         NaN  ...  I10            3.0        NaN
# 4        F10.99      F10.21     F17.210  ...  I10            3.0        NaN
#
#   OTHERDRUGS Risk Score    PTSD PTSD Risk Score  TOBACCO Tobacco Risk Score  \
# ...

# %%
opioid_use_df_copy.rename(columns={'DM_Weights': 'DM Risk Score'}, inplace=True)

# %% [markdown]
# # Risk Score for Back Pain

# %%
url_BP = 'https://docs.google.com/spreadsheets/d/1jIViZdQAMI7vDGKM_5sy_NHd7rV9GHXXq-ac4iqdMNM/export?format=csv'
BP_df = pd.read_csv(url_BP)

# %%
BP_df.tail()
# Out:
#     BACKPAIN                                Backpain_Definition  \
# 23     846.9     Sprain of unspecified site of sacroiliac joint
# 24  S33.5XXA  Sprain of ligaments of lumbar spine, initial e...
# 25    M54.41                  Lumbago with sciatica, right side
# 26  S32.039A  Unspecified fracture of the sacrum, initial en...
# 27    M40.12                 Postural kyphosis, cervical region
#
#     Backpain_Category  Backpain_Chronic  Backpain_Weights  AL Backpain_Labels  \
# 23                  2                 0                 1 NaN             NaN
# 24                  2                 0                 1 NaN             NaN
# 25                  4                 1                 5 NaN             NaN
# 26                  6                 0                 1 NaN             NaN
# 27                  3                 1                 5 NaN             NaN
#
#     Backpain_Number
# 23              NaN
# 24              NaN
# 25              NaN
# 26              NaN
# ...

# %%
BP_df['BACKPAIN'] = BP_df['BACKPAIN'].str.strip()

# %%
BP_df = BP_df[['BACKPAIN','Backpain_Weights']]

# %%
BP_df.head()
# Out:
#    BACKPAIN  Backpain_Weights
# 0     M54.5                 3
# 1     M54.9                 3
# 2  S39.012A                 1
# 3     724.5                 3
# 4     724.3                 5

# %%
opioid_use_df_copy = pd.merge(opioid_use_df_copy, BP_df, left_on='BACKPAIN2017', right_on='BACKPAIN', how='left')

# %%
opioid_use_df_copy.head()
# Out:
#   SEX2019 RACE2019 ETHNICITY2019 AGE_GROUP2019 HTN2017 DM2017 PTSD2017  \
# 0    Male    White       Unknown            25     NaN    NaN      NaN
# 1  Female    Black  Non-Hispanic            66     I10    NaN      NaN
# 2  Female    Black  Non-Hispanic            76     NaN    NaN      NaN
# 3    Male    Black  Non-Hispanic            70     I10  E13.9      NaN
# 4  Female    Black  Non-Hispanic            42     I10    NaN   F43.12
#
#   ADDICTION2017 ALCOHOL2017 TOBACCO2017  ... OTHERDRUGS OTHERDRUGS Risk Score  \
# 0           NaN         NaN         NaN  ...        NaN                   NaN
# 1           NaN         NaN         NaN  ...        NaN                   NaN
# 2           NaN         NaN         NaN  ...        NaN                   NaN
# 3           NaN         NaN         NaN  ...        NaN                   NaN
# 4        F10.99      F10.21     F17.210  ...        NaN                   NaN
#
# ...

# %%
opioid_use_df_copy.rename(columns={'Backpain_Weights': 'Backpain Risk Score'}, inplace=True)

# %% [markdown]
# # Risk Score for Neck Pain

# %%
url_NP = 'https://docs.google.com/spreadsheets/d/1m5UdxRdpT_qlChFm_P4rgKkf8uq2dpbqS6w1shVZr4Q/export?format=csv'
NP_df = pd.read_csv(url_NP)

# %%
NP_df.tail()
# Out:
#     NECKPAIN                                Neckpain_Definition  \
# 32   M47.892                 Other spondylosis, cervical region
# 33     722.4       Degeneration of cervical intervertebral disc
# 34  S13.121A  Subluxation of third cervical vertebra, initia...
# 35  S13.171A  Subluxation of seventh cervical vertebra, init...
# 36     723.4               Brachial neuritis or radiculitis NOS
#
#     Neckpain_Category  Neckpain_Chronic  Neckpain_Weights  Unnamed: 5  \
# 32                  3                 1                 3         NaN
# 33                 10                 1                 1         NaN
# 34                 14                 0                 1         NaN
# 35                 14                 0                 5         NaN
# 36                 18                 1                 1         NaN
#
#    Neckpain_Labels  Neckpain_Number
# 32             NaN              NaN
# 33             NaN              NaN
# 34             NaN              NaN
# ...

# %%
NP_df['NECKPAIN'] = NP_df['NECKPAIN'].str.strip()

# %%
NP_df = NP_df[['NECKPAIN','Neckpain_Weights']]

# %%
NP_df.head()
# Out:
#    NECKPAIN  Neckpain_Weights
# 0       784                 1
# 1     M54.2                 3
# 2     723.1                 3
# 3       721                 3
# 4  S16.1XXA                 1

# %%
opioid_use_df_copy = pd.merge(opioid_use_df_copy, NP_df, left_on='NECKPAIN2017', right_on='NECKPAIN', how='left')

# %%
opioid_use_df_copy.head()
# Out:
#   SEX2019 RACE2019 ETHNICITY2019 AGE_GROUP2019 HTN2017 DM2017 PTSD2017  \
# 0    Male    White       Unknown            25     NaN    NaN      NaN
# 1  Female    Black  Non-Hispanic            66     I10    NaN      NaN
# 2  Female    Black  Non-Hispanic            76     NaN    NaN      NaN
# 3    Male    Black  Non-Hispanic            70     I10  E13.9      NaN
# 4  Female    Black  Non-Hispanic            42     I10    NaN   F43.12
#
#   ADDICTION2017 ALCOHOL2017 TOBACCO2017  ...    PTSD PTSD Risk Score  TOBACCO  \
# 0           NaN         NaN         NaN  ...     NaN             NaN      NaN
# 1           NaN         NaN         NaN  ...     NaN             NaN      NaN
# 2           NaN         NaN         NaN  ...     NaN             NaN      NaN
# 3           NaN         NaN         NaN  ...     NaN             NaN      NaN
# 4        F10.99      F10.21     F17.210  ...  F43.12             3.0  F17.210
#
# ...

# %%
opioid_use_df_copy.rename(columns={'Neckpain_Weights': 'Neckpain Risk Score'}, inplace=True)

# %% [markdown]
# # Risk Score for Cancer

# %%
url_Cancer = 'https://docs.google.com/spreadsheets/d/17WaDfmAvTgvO338z0gxEknEB99gCsvRndGXZw5mv1n4/export?format=csv'
Cancer_df = pd.read_csv(url_Cancer)

# %%
Cancer_df.tail()
# Out:
#      CANCER                                  Cancer_Definition  \
# 32  Z85.828  Personal history of other malignant neoplasm o...
# 33  Z85.831  Personal history of malignant neoplasm of soft...
# 34  Z85.850   Personal history of malignant neoplasm of testis
# 35   Z85.89  Personal history of malignant neoplasm of othe...
# 36    Z85.9  Personal history of malignant neoplasm, unspec...
#
#     Cancer_Category  Cancer_Chronic  Cancer_Weights  Unnamed: 5 Cancer_Labels  \
# 32                1               1               5         NaN           NaN
# 33               13               1               3         NaN           NaN
# 34               10               1               3         NaN           NaN
# 35               12               1               3         NaN           NaN
# 36               12               1               3         NaN           NaN
#
#     Cancer_Number
# 32            NaN
# 33            NaN
# 34            NaN
# 35            NaN
# 36            NaN

# %%
Cancer_df['CANCER'] = Cancer_df['CANCER'].str.strip()

# %%
Cancer_df = Cancer_df[['CANCER','Cancer_Weights']]

# %%
Cancer_df.head()
# Out:
#    CANCER  Cancer_Weights
# 0   172.3               5
# 1   172.6               5
# 2   196.9               3
# 3  202.03               3
# 4   202.1               5

# %%
opioid_use_df_copy = pd.merge(opioid_use_df_copy, Cancer_df, left_on='CANCER2017', right_on='CANCER', how='left')

# %%
opioid_use_df_copy.head()
# Out:
#   SEX2019 RACE2019 ETHNICITY2019 AGE_GROUP2019 HTN2017 DM2017 PTSD2017  \
# 0    Male    White       Unknown            25     NaN    NaN      NaN
# 1  Female    Black  Non-Hispanic            66     I10    NaN      NaN
# 2  Female    Black  Non-Hispanic            76     NaN    NaN      NaN
# 3    Male    Black  Non-Hispanic            70     I10  E13.9      NaN
# 4  Female    Black  Non-Hispanic            42     I10    NaN   F43.12
#
#   ADDICTION2017 ALCOHOL2017 TOBACCO2017  ...  TOBACCO Tobacco Risk Score  \
# 0           NaN         NaN         NaN  ...      NaN                NaN
# 1           NaN         NaN         NaN  ...      NaN                NaN
# 2           NaN         NaN         NaN  ...      NaN                NaN
# 3           NaN         NaN         NaN  ...      NaN                NaN
# 4        F10.99      F10.21     F17.210  ...  F17.210                3.0
#
#       DM DM Risk Score  BACKPAIN Backpain Risk Score NECKPAIN  \
# ...

# %%
opioid_use_df_copy.rename(columns={'Cancer_Weights': 'Cancer Risk Score'}, inplace=True)

# %% [markdown]
# # Risk Score for TBI

# %%
url_TBI = 'https://docs.google.com/spreadsheets/d/16cU_Dk1nY7_EUHKPPwwr-2J6dHDKKddeu9OmcSp1KJY/export?format=csv'
TBI_df = pd.read_csv(url_TBI)

# %%
TBI_df.tail()
# Out:
#          TBI                                     TBI_Definition  TBI_Category  \
# 28       905    (Category not explicitly detailed in your list)            11
# 29  S06.350D  Traumatic hemorrhage of left cerebrum without ...             5
# 30  S06.890D  Other specified intracranial injury without lo...             4
# 31     852.2  Traumatic subdural hemorrhage without loss of ...             5
# 32     850.5  Concussion with loss of consciousness of unspe...             2
#
#     TBI_Chronic  TBI_Weights  Unnamed: 5 TBI_Labels  TBI_Number
# 28            0            1         NaN        NaN         NaN
# 29            0            1         NaN        NaN         NaN
# 30            0            1         NaN        NaN         NaN
# 31            0            1         NaN        NaN         NaN
# 32            0            1         NaN        NaN         NaN

# %%
TBI_df = TBI_df[['TBI','TBI_Weights']]

# %%
TBI_df.head()
# Out:
#         TBI  TBI_Weights
# 0    959.01            1
# 1  S06.0X9A            1
# 2   Z87.820            3
# 3    V15.52            3
# 4  S06.9X9A            1

# %%
opioid_use_df_copy = pd.merge(opioid_use_df_copy, TBI_df, left_on='TBI2017', right_on='TBI', how='left')

# %%
opioid_use_df_copy.head()
# Out:
#   SEX2019 RACE2019 ETHNICITY2019 AGE_GROUP2019 HTN2017 DM2017 PTSD2017  \
# 0    Male    White       Unknown            25     NaN    NaN      NaN
# 1  Female    Black  Non-Hispanic            66     I10    NaN      NaN
# 2  Female    Black  Non-Hispanic            76     NaN    NaN      NaN
# 3    Male    Black  Non-Hispanic            70     I10  E13.9      NaN
# 4  Female    Black  Non-Hispanic            42     I10    NaN   F43.12
#
#   ADDICTION2017 ALCOHOL2017 TOBACCO2017  ...     DM DM Risk Score  BACKPAIN  \
# 0           NaN         NaN         NaN  ...    NaN           NaN       NaN
# 1           NaN         NaN         NaN  ...    NaN           NaN       NaN
# 2           NaN         NaN         NaN  ...    NaN           NaN       NaN
# 3           NaN         NaN         NaN  ...  E13.9           3.0  S39.012A
# 4        F10.99      F10.21     F17.210  ...    NaN           NaN     724.5
#
#   Backpain Risk Score NECKPAIN Neckpain Risk Score CANCER Cancer Risk Score  \
# ...

# %%
opioid_use_df_copy.rename(columns={'TBI_Weights': 'TBI Risk Score'}, inplace=True)

# %% [markdown]
# # Export Data for Models

# %%
# Models to Try: Logistic Regression, Nueral Network,

# %%
opioid_use_df_copy.head()
# Out:
#   SEX2019 RACE2019 ETHNICITY2019 AGE_GROUP2019 HTN2017 DM2017 PTSD2017  \
# 0    Male    White       Unknown            25     NaN    NaN      NaN
# 1  Female    Black  Non-Hispanic            66     I10    NaN      NaN
# 2  Female    Black  Non-Hispanic            76     NaN    NaN      NaN
# 3    Male    Black  Non-Hispanic            70     I10  E13.9      NaN
# 4  Female    Black  Non-Hispanic            42     I10    NaN   F43.12
#
#   ADDICTION2017 ALCOHOL2017 TOBACCO2017 OTHERDRUGS2017 ANXIETY2017  \
# 0           NaN         NaN         NaN            NaN         NaN
# 1           NaN         NaN         NaN            NaN         NaN
# 2           NaN         NaN         NaN            NaN         NaN
# 3           NaN         NaN         NaN            NaN         NaN
# 4        F10.99      F10.21     F17.210            NaN         NaN
#
#   DEPRESSION2017 TBI2017 BACKPAIN2017 NECKPAIN2017 CANCER2017 OPIOIDABUSE2018
# ...

# %%
# Need to drop HASHED_PERSONID, all 2017 columns, etc
pd.set_option('display.max_columns', None)
column_list = opioid_use_df_copy.columns
column_list
# Out:
# Index(['SEX2019', 'RACE2019', 'ETHNICITY2019', 'AGE_GROUP2019', 'HTN2017',
#        'DM2017', 'PTSD2017', 'ADDICTION2017', 'ALCOHOL2017', 'TOBACCO2017',
#        'OTHERDRUGS2017', 'ANXIETY2017', 'DEPRESSION2017', 'TBI2017',
#        'BACKPAIN2017', 'NECKPAIN2017', 'CANCER2017', 'OPIOIDABUSE2018'],
#       dtype='object')

# %%
# remove the codes
columns_to_remove = [
    'HTN2018', 'DM2018', 'PTSD2018','ADDICTION2018', 'ALCOHOL2018', 'TOBACCO2018', 'OTHERDRUGS2018', 'ANXIETY2018', 'DEPRESSION2018', 'TBI2018',
    'BACKPAIN2018', 'NECKPAIN2018', 'CANCER2018', 'HTN2019', 'DM2019', 'PTSD2019','ADDICTION2019', 'ALCOHOL2019', 'TOBACCO2019', 'OTHERDRUGS2019', 'ANXIETY2019', 'DEPRESSION2019', 'TBI2019',
    'BACKPAIN2019', 'NECKPAIN2019', 'CANCER2019', 'OPIOIDABUSE2019'
]
#, 'HASHED_PERSONID'
opioid_use_df_copy = opioid_use_df_copy.drop(columns=columns_to_remove)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-127-7e56d2ec7455> in <cell line: 8>()
#       6 ]
#       7 #, 'HASHED_PERSONID'
# ----> 8 opioid_use_df_copy = opioid_use_df_copy.drop(columns=columns_to_remove)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5342                 weight  1.0     0.8
#    5343         """
# -> 5344         return super().drop(
#    5345             labels=labels,
#    5346             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709         for axis, labels in axes.items():
#    4710             if labels is not None:
# -> 4711                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4712
# ...

# %%
opioid_use_df_copy.shape
# Out:
# (199999, 51)

# %%
opioid_use_df_copy.head()
# Out:
#   SEX2019 RACE2019 ETHNICITY2019 AGE_GROUP2019 HTN2017 DM2017 PTSD2017  \
# 0    Male    White       Unknown            25     NaN    NaN      NaN
# 1  Female    Black  Non-Hispanic            66     I10    NaN      NaN
# 2  Female    Black  Non-Hispanic            76     NaN    NaN      NaN
# 3    Male    Black  Non-Hispanic            70     I10  E13.9      NaN
# 4  Female    Black  Non-Hispanic            42     I10    NaN   F43.12
#
#   ADDICTION2017 ALCOHOL2017 TOBACCO2017 OTHERDRUGS2017 ANXIETY2017  \
# 0           NaN         NaN         NaN            NaN         NaN
# 1           NaN         NaN         NaN            NaN         NaN
# 2           NaN         NaN         NaN            NaN         NaN
# 3           NaN         NaN         NaN            NaN         NaN
# 4        F10.99      F10.21     F17.210            NaN         NaN
#
#   DEPRESSION2017 TBI2017 BACKPAIN2017 NECKPAIN2017 CANCER2017 OPIOIDABUSE2017  \
# ...

# %%
opioid_use_df_copy['Alcohol Risk Score'] = opioid_use_df_copy['Alcohol Risk Score'].fillna(0)
opioid_use_df_copy['Addiction Risk Score'] = opioid_use_df_copy['Addiction Risk Score'].fillna(0)
opioid_use_df_copy['Anxiety Risk Score'] = opioid_use_df_copy['Anxiety Risk Score'].fillna(0)
opioid_use_df_copy['HTN Risk Score'] = opioid_use_df_copy['HTN Risk Score'].fillna(0)
opioid_use_df_copy['OTHERDRUGS Risk Score'] = opioid_use_df_copy['OTHERDRUGS Risk Score'].fillna(0)
opioid_use_df_copy['PTSD Risk Score'] = opioid_use_df_copy['PTSD Risk Score'].fillna(0)
opioid_use_df_copy['Tobacco Risk Score'] = opioid_use_df_copy['Tobacco Risk Score'].fillna(0)
opioid_use_df_copy['DM Risk Score'] = opioid_use_df_copy['DM Risk Score'].fillna(0)
opioid_use_df_copy['Backpain Risk Score'] = opioid_use_df_copy['Backpain Risk Score'].fillna(0)
opioid_use_df_copy['Neckpain Risk Score'] = opioid_use_df_copy['Neckpain Risk Score'].fillna(0)
opioid_use_df_copy['Cancer Risk Score'] = opioid_use_df_copy['Cancer Risk Score'].fillna(0)
opioid_use_df_copy['TBI Risk Score'] = opioid_use_df_copy['TBI Risk Score'].fillna(0)
opioid_use_df_copy['Depression Risk Score'] = opioid_use_df_copy['Depression Risk Score'].fillna(0)

# %%
opioid_use_df_copy.to_csv('/content/drive/Shareddrives/Capstone Project: GHUCCTS/Life Stress DT Capstone Project/Code/opioid_training_data.csv', index=False)
